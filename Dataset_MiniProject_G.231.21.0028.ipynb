# %%
#Import Library
import datetime
import pandas as pd
#Baca Dataset
dataset = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/retail_raw_reduced.csv')
dataset.head(20)
# Out:
#     order_id  order_date  customer_id             city     province  \
# 0    1703458  2019-10-17        14004  Jakarta Selatan  DKI Jakarta
# 1    1706815  2019-10-24        17220  Jakarta Selatan  DKI Jakarta
# 2    1710718  2019-11-03        16518    Jakarta Utara  DKI Jakarta
# 3    1683592  2019-08-19        16364    Jakarta Barat  DKI Jakarta
# 4    1702573  2019-10-16        15696    Jakarta Timur  DKI Jakarta
# 5    1672906  2019-07-16        12748    Jakarta Utara  DKI Jakarta
# 6    1711399  2019-11-04        16791    Jakarta Barat  DKI Jakarta
# 7    1695367  2019-09-26        13069        Surakarta  Jawa Tengah
# 8    1741846  2019-12-30        16873    Jakarta Barat  DKI Jakarta
# 9    1720189  2019-11-24        14723        Tangerang       Banten
# 10   1683583  2019-08-19        13814         Denpasar         Bali
# 11   1693309  2019-09-19        17841    Jakarta Utara  DKI Jakarta
# 12   1708381  2019-10-29        13895        Tangerang       Banten
# ...

# %%
dataset.tail(10)
# Out:
#       order_id  order_date  customer_id             city     province  \
# 4990   1678408  2019-08-02        15182    Jakarta Pusat  DKI Jakarta
# 4991   1736503  2019-12-20        18109        Tangerang       Banten
# 4992   1734787  2019-12-18        18283  Jakarta Selatan  DKI Jakarta
# 4993   1678615  2019-08-04        16880           Bekasi   Jawa Barat
# 4994   1707424  2019-10-25        13021       Yogyakarta   Yogyakarta
# 4995   1724011  2019-12-01        12838        Tangerang       Banten
# 4996   1676302  2019-07-28        13833            Bogor   Jawa Barat
# 4997   1706071  2019-10-23        16332    Jakarta Timur  DKI Jakarta
# 4998   1703620  2019-10-17        13055    Jakarta Barat  DKI Jakarta
# 4999   1720036  2019-11-24        17609    Jakarta Pusat  DKI Jakarta
#
#      product_id    brand  quantity  item_price
# 4990      P1903  BRAND_J        10      740000
# 4991      P2866  BRAND_R         3     1045000
# 4992      P0734  BRAND_C         2      310000
# ...
